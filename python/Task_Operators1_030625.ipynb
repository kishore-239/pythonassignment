# %% [markdown]
# # OPERATORS

# %% [markdown]
# ### Q.1

# %%
# 1. John has 6 apples and 7 bananas. How many fruits does John have?

# %%
apples = 6
bananas = 7

# %%
total = apples + bananas

# %%
print(f"John have {total} fruits ")
# Out:
# John have 13 fruits

# %% [markdown]
# ### Q.2

# %%
# 2. Emma read 15 pages yesterday and 10 pages today. Did she read more than 20 pages in total?

# %%
yesterday = 15
today = 10

# %%
total = yesterday + today

# %%
# Did she read more than 20 pages in total?

if total >= 20:
    print("Yes, she read more than 20 pages in total.")
else:
    print("No.")
# Out:
# Yes, she read more than 20 pages in total.

# %% [markdown]
# ### Q.3

# %%
# 3. A bag contains 12 red balls and 8 blue balls. Is the number of red balls greater than blue balls?

# %%
red = 12
blue = 8

# %%
if red > blue:
    print("Yes, number of red balls is greater than blue balls")
else:
    print("No")
# Out:
# Yes, number of red balls is greater than blue balls

# %% [markdown]
# ### Q.4

# %%
# 4. Mike had 30 candies and gave 12 to his friend. How many does he have now?

# %%
mike = 30
friend = 12

# %%
remaining = mike - friend

# %%
print(f"Mike have {remaining} candies left from 30 candies after giving 12 candies to his friend")
# Out:
# Mike have 18 candies left from 30 candies after giving 12 candies to his friend

# %% [markdown]
# ### Q.5

# %%
# 5. Sarah bought 5 pens at $3 each. How much did she spend?

# %%
pens = 5
cost = 3

# %%
spend = pens * cost

# %%
print(f"Sarah spent {spend}$ on buying pens")
# Out:
# Sarah spent 15$ on buying pens

# %% [markdown]
# ### Q.6

# %%
# 6. There are 45 cookies equally divided among 5 kids. How many does each get?

# %%
cookies = 45
kids = 5

# %%
each = cookies//kids

# %%
print(f"Every kid gets {each} cookies each")
# Out:
# Every kid gets 9 cookies each

# %% [markdown]
# ### Q.7

# %%
# 7. Tom scored 89 in math and 76 in science. Did he score more than 160 in total?

# %%
math = 89
science = 76

# %%
total = math + science

# %%
if total > 160:
    print(f"Yes, Tom got {total} and scored more than 160 in total")
else:
    print(f"No, Tom got {total} and failed to score more than 160 in total")
# Out:
# Yes, Tom got 165 and scored more than 160 in total

# %% [markdown]
# ### Q.8

# %%
# 8. A store sells apples at $2.50 each. If you buy 4, is the total cost more than $10?

# %%
cost = 2.5
apples = 4

# %%
total = cost * apples

# %%
if total > 10:
    print(f"Yes, the total cost is ${total} and it is more than $10")
else:
    print(f"No, The total cost is not more than $10")
# Out:
# No, The total cost is not more than $10

# %% [markdown]
# ### Q.9

# %%
# 9. Alice has $100 and buys 3 books for $25 each. Will she have any money left?

# %%
total = 100
books = 3
cost = 25

# %%
spent = books * cost

# %%
if total > spent:
    print("Yes, she had money left after buying books")
else:
    print("No, she had no money left with her")
# Out:
# Yes, she had money left after buying books

# %% [markdown]
# ### Q.10

# %%
# 10. A rectangle has length 10 and width 4. Is its area greater than its perimeter?

# %%
length = 10
width = 4

# %%
area = length * width
perimeter = 2 * (length + width)

# %%
if area > perimeter:
    print("Yes, area is greater than its perimeter")
else:
    print("No, area is less than its perimeter")
# Out:
# Yes, area is greater than its perimeter

# %% [markdown]
# ### Q.11

# %%
# 11. Two friends have 45 and 55 marbles respectively. Do they have equal number of marbles?

# %%
friend_1 = 45
friend_2 = 55

# %%
if friend_1 == friend_2:
    print("Yes, they have equal no.of marbles")
else:
    print("No, they have inequal no.of marbles")
# Out:
# No, they have inequal no.of marbles

# %% [markdown]
# ### Q.12

# %%
# 12. A car travels 60 km in 1 hour and a bike 40 km in the same time. Is the car faster?

# %%
car_d = 60
time = 1
bike_d = 40

# %%
car_s = car_d/time
bike_s = bike_d/time

# %%
if car_s > bike_s:
    print("Yes, car is faster than bike")
else:
    print("No, car is not faster")
# Out:
# Yes, car is faster than bike

# %% [markdown]
# ### Q.13

# %%
# 13. A chocolate costs $2. You have $9. Can you buy 5 chocolates?

# %%
cost = 2
budget = 9
buy = 5

# %%
total = cost * buy

# %%
if budget > total:
    print("Yes, I can buy 5 chocolates")
else:
    print("No, I cannot buy 5 chocolates")
# Out:
# No, I cannot buy 5 chocolates

# %% [markdown]
# ### Q.14

# %%
# 14. A container holds 100 liters of water. If 30 liters are used, is more than half remaining?

# %%
container = 100
used = 30

# %%
remaining = container - used
half = container//2

# %%
if remaining > half:
    print("Yes, it is more than half remaining")
else:
    print("No, it is less than half remaining")
# Out:
# Yes, it is more than half remaining

# %% [markdown]
# ### Q.15

# %%
# 15. Two numbers are 13 and 17. Is their sum an even number?

# %%
number1 = 13
number2 = 17

# %%
sum = number1 + number2

# %%
if sum%2 == 0:
    print("Yes, their sum is an even number")
else:
    print("No, their sum is not an even number")
# Out:
# Yes, their sum is an even number

# %% [markdown]
# ### Q.16

# %%
# 16. Peter has 5 books, each weighing 1.2 kg. Is the total weight more than 6 kg?

# %%
books = 5
each = 1.2

# %%
total = books * each

# %%
if total > 6:
    print("Yes, the total weight is more than 6 kg")
else:
    print("No, the total weight is not more than 6 kg")
# Out:
# No, the total weight is not more than 6 kg

# %% [markdown]
# ### Q.17

# %%
# 17. A triangle has sides 3, 4, and 5. Is it a right-angled triangle?

# %%
a = 3
b = 4
c = 5

# %%
X = pow(c,2)
Y = pow(a,2) + pow(b,2)

# %%
if X == Y:
    print("Yes, it is a right-angled triangle")
else:
    print("No, it is not a right-angled triangle")
# Out:
# Yes, it is a right-angled triangle

# %% [markdown]
# ### Q.18

# %%
# 18. Jenny had $50, bought items worth $35. Does she have less than $20 left?

# %%
budget = 50
worth = 35

# %%
remaining = budget - worth

# %%
if remaining < 20:
    print("Yes, she have less than $20 left")
else:
    print("No, she doesn't have less than $20 left")
# Out:
# Yes, she have less than $20 left

# %% [markdown]
# ### Q.19

# %%
# 19. A worker earns $80 per day. Is earning from 6 days more than $500?

# %%
day_earn = 80
days = 6

# %%
earning = days * day_earn

# %%
if earning > 500:
    print("Yes, his earning from 6 days is more than $500")
else:
    print("No, his earning from 6 days is not more than $500")
# Out:
# No, his earning from 6 days is not more than $500

# %% [markdown]
# ### Q.20

# %%
# 20. A movie ticket costs $12. Can you buy 4 with $50?

# %%
cost = 12
buy = 4
budget = 50

# %%
spent = cost * buy

# %%
if budget > spent:
    print("Yes, I can buy")
else:
    print("NO, I cannot buy")
# Out:
# Yes, I can buy

# %% [markdown]
# ### Q.21

# %%
# 21. If a bottle contains 750ml, do 4 bottles hold more than 3 liters?

# %%
bottle = 750
quantity = 4

# %%
total = bottle * quantity

# %%
if total > 3000:
    print("Yes, 4 bottles do hold more than 3 liters")
else:
    print("No, 4 bottles do not hold more than 3 liters")
# Out:
# No, 4 bottles do not hold more than 3 liters

# %% [markdown]
# ### Q.22

# %%
# 22. Is the difference between 100 and 37 greater than 60?

# %%
a = 100
b = 37

# %%
c = a - b

# %%
if c > 60:
    print("Yes, the difference is greater than 60")
else:
    print("No, the difference is not greater than 60")
# Out:
# Yes, the difference is greater than 60

# %% [markdown]
# ### Q.23

# %%
# 23. Does dividing 81 by 9 result in a number greater than 8?

# %%
a = 81
b = 9

# %%
c = a/b

# %%
if c > 8:
    print("Yes, result is greater than 8")
else:
    print("No, result is not greater than 8")
# Out:
# Yes, result is greater than 8

# %% [markdown]
# ### Q.24

# %%
# 24. Are 5 multiplied by 6 and 30 equal?

# %%
a = 5
b = 6

# %%
c = a * b

# %%
if c == 30:
    print("Yes, 5 multiplied by 6 and 30 are equal")
else:
    print("No, 5 multiplied by 6 and 30 are not equal")
# Out:
# Yes, 5 multiplied by 6 and 30 are equal

# %% [markdown]
# ### Q.25

# %%
# 25. Do two squares of side 4 and 5 have the same area?

# %%
a = 4
b = 5

# %%
area1 = pow(4,2)
area2 = pow(5,2)

# %%
if area1 == area2:
    print("Yes, they have same area")
else:
    print("No, they have different area")
# Out:
# No, they have different area

# %% [markdown]
# ### Q.26

# %%
# 26. A basket holds 18 apples. If you eat 6, do you have fewer than 15 left?

# %%
apples = 18
eat = 6

# %%
left = apples - eat

# %%
if left < 15:
    print("Yes, I have fewer than 15 left")
else:
    print("No, I have more than 15 left")
# Out:
# Yes, I have fewer than 15 left

# %% [markdown]
# ### Q.27

# %%
# 27. Sam travels 120 km in 2 hours. Is his speed 60 km/hr?

# %%
a = 120
b = 2

# %%
c = a/b

# %%
if c == 60:
    print("Yes, his speed is 60km/hr")
else:
    print("No, his speed is not 60km/hr")
# Out:
# Yes, his speed is 60km/hr

# %% [markdown]
# ### Q.28

# %%
# 28. Is 7 + 3 * 2 equal to 20?

# %%
a = 7 + 3 * 2

# %%
if a == 20:
    print("Yes, 7 + 3 * 2 is equal to 20")
else:
    print("No, 7 + 3 * 2 is not equal to 20")
# Out:
# No, 7 + 3 * 2 is not equal to 20

# %% [markdown]
# ### Q.29

# %%
# 29. Jane bought 2 pens and 3 pencils. If a pen is $2 and pencil $1, did she spend $9?

# %%
pens = 2
pencils = 3

# %%
cost_pens = pens * 2
cost_pencils = pencils * 1

# %%
spent = cost_pens + cost_pencils

# %%
if spent == 9:
    print("Yes, she did spend $9")
else:
    print("No, she didn't spend $9")
# Out:
# No, she didn't spend $9

# %% [markdown]
# ### Q.30

# %%
# 30. You have 3 boxes, each holding 12 balls. Are total balls more than 35?

# %%
boxes = 3
quantity = 12

# %%
total = boxes * quantity

# %%
if total > 35:
    print("Yes, total balls are more than 35")
else:
    print("No, total balls are not more than 35")
# Out:
# Yes, total balls are more than 35

# %% [markdown]
# ### Q.31

# %%
# 31. A triangle has angles 60, 60, and 60. Do they sum to 180?

# %%
a = b = c = 60

# %%
sum = a + b + c

# %%
if sum == 180:
    print("Yes, they sum upto 180")
else:
    print("No, they don't sum upto 180")
# Out:
# Yes, they sum upto 180

# %% [markdown]
# ### Q.32

# %%
# 32. If you split 100 into two equal parts, is one part greater than 60?

# %%
a = 100
b = a/2

# %%
if b > 60:
    print("Yes, one part is greater than 60")
else:
    print("No, one part is not greater than 60")
# Out:
# No, one part is not greater than 60

# %% [markdown]
# ### Q.33

# %%
# 33. Mike earned $400 in 8 days. Did he earn $50 daily?

# %%
total = 400
days = 8

# %%
day = total/days

# %%
if day == 50:
    print("Yes, he earn $50 daily")
else:
    print("No, he don't earn $50 daily")
# Out:
# Yes, he earn $50 daily

# %% [markdown]
# ### Q.34

# %%
# 34. Does subtracting 20 from 50 give 30?

# %%
a = 20
b = 50

# %%
c = b - a

# %%
if c == 30:
    print("Yes, subtraction gives 30")
else:
    print("No, subtraction doesn't gives 30")
# Out:
# Yes, subtraction gives 30

# %% [markdown]
# ### Q.35

# %%
# 35. Are 10 + 15 and 5 * 5 equal?

# %%
a = 10 + 15
b = 5 * 5

# %%
if a == b:
    print("Yes, they are equal")
else:
    print("No, they are not equal")
# Out:
# Yes, they are equal

# %% [markdown]
# ### Q.36

# %%
# 36. If a packet has 48 candies, can 6 kids get more than 7 each?

# %%
packet = 48
kids = 6

# %%
each = packet/kids

# %%
if each > 7:
    print("Yes, 6 kids can get more than 7 each")
else:
    print("No, 6 kids cannot get more than 7 each")
# Out:
# Yes, 6 kids can get more than 7 each

# %% [markdown]
# ### Q.37

# %%
# 37. Compare 5 ** 2 and 25. Are they the same?

# %%
a = 5 ** 2
b = 25

# %%
if a == b:
    print("Yes, they are same")
else:
    print("No, they are not same")
# Out:
# Yes, they are same

# %% [markdown]
# ### Q.38

# %%
# 38. Is (10 + 2) * 3 greater than 35?

# %%
a = (10 + 2) * 3
b = 35

# %%
if a > b:
    print("Yes, (10 + 2) * 3 is greater than 35")
else:
    print("No, (10 + 2) * 3 is not greater than 35")
# Out:
# Yes, (10 + 2) * 3 is greater than 35

# %% [markdown]
# ### Q.39

# %%
# 39. Do 8 and 8.0 compare equal?

# %%
a = 8
b = 8.0

# %%
if a == b:
    print("Yes, 8 and 8.0 do compare equal")
else:
    print("No, 8 and 8.0 do not compare equal")
# Out:
# Yes, 8 and 8.0 do compare equal

# %% [markdown]
# ### Q.40

# %%
# 40. A rope is cut into 3 pieces of 10, 15, and 25 meters. Is the total 50?

# %%
a = 10
b = 15
c = 25

# %%
d = a + b + c

# %%
if d == 50:
    print("Yes, the total is 50")
else:
    print("No, the total is not 50")
# Out:
# Yes, the total is 50

# %% [markdown]
# ### Q.41

# %%
# 41. Multiply 4 by 4. Is the result less than 20?

# %%
a = 4 * 4

# %%
if a < 20:
    print("Yes, the result is less than 20")
else:
    print("No, the result is not less than 20")
# Out:
# Yes, the result is less than 20

# %% [markdown]
# ### Q.42

# %%
# 42. Add 13 and 7. Is the result divisible by 5?

# %%
a = 13 + 7

# %%
if a % 5 == 0:
    print("Divisible")
else:
    print("Not divisible")
# Out:
# Divisible

# %% [markdown]
# ### Q.43

# %%
# 43. 20 apples are equally shared between 5 students. Does each get 4?

# %%
apples = 20
students = 5

# %%
each = apples/students

# %%
if each == 4:
    print("Yes, each student gets 4")
else:
    print("No, they dont get 4 each")
# Out:
# Yes, each student gets 4

# %% [markdown]
# ### Q.44

# %%
# 44. Subtract 15 from 60. Is the result equal to 45?

# %%
a = 60 -15

# %%
if a == 45:
    print("the result is equal to 45")
else:
    print("the result is not equal to 45")
# Out:
# the result is equal to 45

# %% [markdown]
# ### Q.45

# %%
# 45. Compare 3 * 3 + 1 and 10. Are they equal?

# %%
a = 3 * 3 + 1
b = 10

# %%
if a == b:
    print("They are equal")
else:
    print("They are not equal")
# Out:
# They are equal

# %% [markdown]
# ### Q.46

# %%
# 46. If you double 12, is the result more than 25?

# %%
a = 12 * 2

# %%
if a > 25:
    print("the result is more than 25")
else:
    print("the result is not more than 25")
# Out:
# the result is not more than 25

# %% [markdown]
# ### Q.47

# %%
# 47. Are 100 divided by 4 and 25 equal?

# %%
a = 100/4
b = 25

# %%
if a == b:
    print("They are equal")
else:
    print("They are not equal")
# Out:
# They are equal

# %% [markdown]
# ### Q.48

# %%
# 48. Is (9 - 3) * 2 greater than 10?

# %%
a = (9 - 3) * 2
b = 10

# %%
if a > b:
    print("Yes")
else:
    print("No")
# Out:
# Yes

# %% [markdown]
# ### Q.49

# %%
#49. If you have $99 and spend $33 three times, will anything be left?

# %%
a = 99
b = 33 * 3

# %%
if a > b:
    print("I have money left")
else:
    print("No money left")
# Out:
# No money left

# %% [markdown]
# ### Q.50

# %%
# 50. Add 5.5 and 4.5. Is the result 10?

# %%
a = 4.5 + 5.5
b = 10

# %%
if a == b:
    print("Yes, the result is 10")
else:
    print("No, the result is not 10")
# Out:
# Yes, the result is 10
