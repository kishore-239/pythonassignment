# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# %%
import numpy as np 
import os

import pandas as pd

# %% [markdown]
# ### Q:
# 1. What type of data does each column in the Iris dataset contain?
# 2. What are the dimensions of the Iris dataset?
# 3. How many unique species of flowers are present in the dataset, and what are their names?
# 4. Check if there are any NaN values in the dataset.
# 5. Convert the "Id" column from int to float.
# 6. What is the range of values for the `SepalLengthCm` and `PetalWidthCm`?
# 7. What is the mean and median of the `PetalLengthCm` column?
# 8. What does the `df.describe().T` function do, and how can it help in EDA? Interpret the output.
# 9. How would you select the first five rows of the Iris dataset using `iloc`?
# 10. How can you access the 'PetalLengthCm' column for rows where the species is 'Iris-setosa' using `loc`?
# 11. How would you filter the dataset to include only rows where `SepalLengthCm > 5.0` and `PetalWidthCm < 1.5` using `&`?
# 12. Using `loc` and `&` to select rows labeled 'Iris-versicolor' where `SepalLengthCm` is between 5.5 and 6.5.
# 13. Using `loc` and `|` to filter rows labeled 'Iris-virginica' or 'Iris-setosa' with `PetalWidthCm > 2.0`.

# %%
df = pd.read_csv(r"C:\Users\kisho\OneDrive\Desktop\All semesters\Innomatics #405\2_EDA\Task_200825_Iris & Chipotle  Case Study\Iris.csv")
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
print(df.dtypes)
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
df.shape
# Out:
# (150, 6)

# %%
df['Species'].nunique()
df['Species'].unique()
# Out:
# 3
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
df.isna().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
print(df['Id'].dtype)
# Out:
# int64

# %%
df['SepalLengthCm'].min()
df['SepalLengthCm'].max()
# Out:
# 4.3
# 7.9

# %%
print(df['PetalLengthCm'].mean())
df['PetalLengthCm'].median()
# Out:
# 3.758666666666666
# 4.35

# %%
df.describe().T
# Out:
#                count       mean        std  min    25%    50%     75%    max
# Id             150.0  75.500000  43.445368  1.0  38.25  75.50  112.75  150.0
# SepalLengthCm  150.0   5.843333   0.828066  4.3   5.10   5.80    6.40    7.9
# SepalWidthCm   150.0   3.054000   0.433594  2.0   2.80   3.00    3.30    4.4
# PetalLengthCm  150.0   3.758667   1.764420  1.0   1.60   4.35    5.10    6.9
# PetalWidthCm   150.0   1.198667   0.763161  0.1   0.30   1.30    1.80    2.5

# %%
df.iloc[:5]
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.loc[df['Species']=='Iris-setosa', 'PetalLengthCm']
# Out:
# 0     1.4
# 1     1.4
# 2     1.3
# 3     1.5
# 4     1.4
# 5     1.7
# 6     1.4
# 7     1.5
# 8     1.4
# 9     1.5
# 10    1.5
# 11    1.6
# 12    1.4
# 13    1.1
# 14    1.2
# 15    1.5
# 16    1.3
# 17    1.4
# 18    1.7
# 19    1.5
# 20    1.7
# 21    1.5
# 22    1.0
# 23    1.7
# 24    1.9
# 25    1.6
# 26    1.6
# 27    1.5
# 28    1.4
# 29    1.6
# 30    1.6
# 31    1.5
# 32    1.5
# 33    1.4
# 34    1.5
# 35    1.2
# 36    1.3
# 37    1.5
# 38    1.3
# 39    1.5
# 40    1.3
# 41    1.3
# 42    1.3
# 43    1.6
# 44    1.9
# 45    1.4
# 46    1.6
# 47    1.4
# 48    1.5
# 49    1.4
# Name: PetalLengthCm, dtype: float64

# %%
a = df[(df['SepalLengthCm'] > 5.0) & (df['PetalWidthCm'] < 1.5)]
a
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 5      6            5.4           3.9            1.7           0.4
# 10    11            5.4           3.7            1.5           0.2
# 14    15            5.8           4.0            1.2           0.2
# 15    16            5.7           4.4            1.5           0.4
# 16    17            5.4           3.9            1.3           0.4
# 17    18            5.1           3.5            1.4           0.3
# 18    19            5.7           3.8            1.7           0.3
# 19    20            5.1           3.8            1.5           0.3
# 20    21            5.4           3.4            1.7           0.2
# 21    22            5.1           3.7            1.5           0.4
# 23    24            5.1           3.3            1.7           0.5
# 27    28            5.2           3.5            1.5           0.2
# ...

# %%
b = df.loc[(df['Species']=='Iris-versicolor') & (df['SepalLengthCm'].between(5.5, 6.5))]
b
# Out:
#      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 51   52            6.4           3.2            4.5           1.5
# 53   54            5.5           2.3            4.0           1.3
# 54   55            6.5           2.8            4.6           1.5
# 55   56            5.7           2.8            4.5           1.3
# 56   57            6.3           3.3            4.7           1.6
# 61   62            5.9           3.0            4.2           1.5
# 62   63            6.0           2.2            4.0           1.0
# 63   64            6.1           2.9            4.7           1.4
# 64   65            5.6           2.9            3.6           1.3
# 66   67            5.6           3.0            4.5           1.5
# 67   68            5.8           2.7            4.1           1.0
# 68   69            6.2           2.2            4.5           1.5
# 69   70            5.6           2.5            3.9           1.1
# ...

# %%
c = df.loc[((df['Species']=='Iris-virginica') | (df['Species']=='Iris-setosa')) & (df['PetalWidthCm'] > 2.0)]
c
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 100  101            6.3           3.3            6.0           2.5
# 102  103            7.1           3.0            5.9           2.1
# 104  105            6.5           3.0            5.8           2.2
# 105  106            7.6           3.0            6.6           2.1
# 109  110            7.2           3.6            6.1           2.5
# 112  113            6.8           3.0            5.5           2.1
# 114  115            5.8           2.8            5.1           2.4
# 115  116            6.4           3.2            5.3           2.3
# 117  118            7.7           3.8            6.7           2.2
# 118  119            7.7           2.6            6.9           2.3
# 120  121            6.9           3.2            5.7           2.3
# 124  125            6.7           3.3            5.7           2.1
# 128  129            6.4           2.8            5.6           2.1
# ...

# %% [markdown]
# ### Chipotle Dataset Analysis
#
# 1. Remove the $ symbol from the item_price column and convert it to numeric data.
#
# 2. How many products cost more than $10?
#
# 3. What is the maximum price of the Chicken Bowl item?
#
# 4. Extract the unique item_name available for less than $5.
#
# 5. Identify the order_id that has placed the most orders.
#
# 6. Which is the most ordered item_name?
#
# 7. Find the minimum and maximum price in the item_price column.
#
# 8. Find the most expensive dish (item_name).
#
# 9. Calculate the total amount for orders where the item_name is Canned Soft Drink and the choice_description is Lemonade.
#
# 10. Use loc to extract all orders where the item_price is greater than $10 and belongs to the Chicken Bowl.
#
# 11. Use iloc to extract the first 10 rows of the dataset and display only order_id, item_name, and item_price.
#
# 12. Find the top 3 most ordered items.
#
# 13. Extract all unique choice_description for items costing more than $15.
#
# 14. Find the total quantity of Veggie Salad Bowl sold.
#
# 15. Find the total revenue generated for each item_name and list the top 5 unique items by revenue.

# %%
df = pd.read_csv(r"C:\Users\kisho\OneDrive\Desktop\All semesters\Innomatics #405\2_EDA\Task_200825_Iris & Chipotle  Case Study\chipotle.csv")
df
# Out:
#      order_id  quantity                              item_name  \
# 0           1         1           Chips and Fresh Tomato Salsa
# 1           1         1                                   Izze
# 2           1         1                       Nantucket Nectar
# 3           1         1  Chips and Tomatillo-Green Chili Salsa
# 4           2         2                           Chicken Bowl
# ..        ...       ...                                    ...
# 994       408         1                           Chicken Bowl
# 995       409         1                           Chicken Bowl
# 996       409         1                           Chicken Bowl
# 997       410         1                        Chicken Burrito
# 998       410         1                      Canned Soft Drink
#
#                                     choice_description item_price
# 0                                                  NaN     $2.39
# 1                                         [Clementine]     $3.39
# ...

# %%
df['item_price'] = df['item_price'].str.replace('$','', regex=False).astype(float)

# %%
df[df['item_price'] > 10].shape[0]
# Out:
# 226

# %%
df.loc[df['item_name']=='Chicken Bowl', 'item_price'].max()
# Out:
# 32.94

# %%
df.loc[df['item_price'] < 5, 'item_name'].unique()
# Out:
# array(['Chips and Fresh Tomato Salsa', 'Izze', 'Nantucket Nectar',
#        'Chips and Tomatillo-Green Chili Salsa', 'Side of Chips',
#        'Chips and Guacamole', 'Canned Soda', 'Bottled Water',
#        'Chips and Tomatillo Green Chili Salsa', 'Chips',
#        'Chips and Tomatillo Red Chili Salsa',
#        'Chips and Roasted Chili-Corn Salsa',
#        'Chips and Roasted Chili Corn Salsa', 'Canned Soft Drink',
#        'Chips and Tomatillo-Red Chili Salsa',
#        'Chips and Mild Fresh Tomato Salsa'], dtype=object)

# %%
print(df['order_id'].value_counts().idxmax())
# Out:
# 205

# %%
df['item_name'].value_counts().idxmax()
# Out:
# 'Chicken Burrito'

# %%
df['item_price'].min()
df['item_price'].max()
# Out:
# 1.09
# 32.94

# %%
a = df.loc[df['item_price'].idxmax(), 'item_name']
a
# Out:
# 'Chicken Bowl'

# %%
b = df.loc[(df['item_name']=='Canned Soft Drink') & 
                      (df['choice_description']=='[Lemonade]'), 'item_price'].sum()

print(b)
# Out:
# 12.5

# %%
c = df.loc[(df['item_name']=='Chicken Bowl') & (df['item_price'] > 10)]
c
# Out:
#      order_id  quantity     item_name  \
# 4           2         2  Chicken Bowl
# 5           3         1  Chicken Bowl
# 13          7         1  Chicken Bowl
# 42         20         1  Chicken Bowl
# 123        54         1  Chicken Bowl
# 138        62         1  Chicken Bowl
# 140        63         1  Chicken Bowl
# 142        64         1  Chicken Bowl
# 154        70         2  Chicken Bowl
# 176        79         1  Chicken Bowl
# 199        89         1  Chicken Bowl
# 209        93         1  Chicken Bowl
# 211        93         1  Chicken Bowl
# 282       124         2  Chicken Bowl
# 290       126         1  Chicken Bowl
# 291       127         1  Chicken Bowl
# 303       132         1  Chicken Bowl
# 379       165         1  Chicken Bowl
# 407       177         1  Chicken Bowl
# 409       178         3  Chicken Bowl
# 411       179         1  Chicken Bowl
# 415       181         2  Chicken Bowl
# 454       195         1  Chicken Bowl
# ...

# %%
df.iloc[:10][['order_id','item_name','item_price']]
# Out:
#    order_id                              item_name  item_price
# 0         1           Chips and Fresh Tomato Salsa        2.39
# 1         1                                   Izze        3.39
# 2         1                       Nantucket Nectar        3.39
# 3         1  Chips and Tomatillo-Green Chili Salsa        2.39
# 4         2                           Chicken Bowl       16.98
# 5         3                           Chicken Bowl       10.98
# 6         3                          Side of Chips        1.69
# 7         4                          Steak Burrito       11.75
# 8         4                       Steak Soft Tacos        9.25
# 9         5                          Steak Burrito        9.25

# %%
df['item_name'].value_counts().head(3)
# Out:
# item_name
# Chicken Burrito        125
# Chicken Bowl           119
# Chips and Guacamole    110
# Name: count, dtype: int64

# %%
df.loc[df['item_price'] > 15, 'choice_description'].unique()
# Out:
# array(['[Tomatillo-Red Chili Salsa (Hot), [Black Beans, Rice, Cheese, Sour Cream]]',
#        '[Tomatillo Green Chili Salsa, [Sour Cream, Cheese, Guacamole]]',
#        '[Tomatillo-Red Chili Salsa (Hot), [Rice, Cheese, Sour Cream, Lettuce]]',
#        '[Tomatillo Red Chili Salsa, [Rice, Black Beans, Sour Cream, Cheese, Lettuce]]',
#        '[Fresh Tomato Salsa, [Fajita Vegetables, Rice, Lettuce]]',
#        '[Fresh Tomato Salsa, [Fajita Vegetables, Pinto Beans, Guacamole]]',
#        '[Tomatillo Red Chili Salsa, [Cheese, Sour Cream, Lettuce]]',
#        '[Tomatillo Red Chili Salsa, [Rice, Black Beans, Cheese, Sour Cream, Lettuce]]',
#        '[Tomatillo Red Chili Salsa, [Black Beans, Cheese, Guacamole]]',
#        '[Fresh Tomato Salsa, [Rice, Black Beans, Cheese, Sour Cream]]',
#        '[Fresh Tomato Salsa, Fajita Vegetables]',
#        '[Fresh Tomato (Mild), [Lettuce, Guacamole, Rice, Cheese]]',
#        '[Fresh Tomato Salsa, Sour Cream]',
# ...

# %%
d = df.loc[df['item_name']=='Veggie Salad Bowl', 'quantity'].sum()
print(d)
# Out:
# 5

# %%
df['revenue'] = df['quantity'] * df['item_price']
a = df.groupby('item_name')['revenue'].sum().sort_values(ascending=False).head(5)
a
# Out:
# item_name
# Chicken Bowl           1384.22
# Chicken Burrito        1240.74
# Steak Burrito          1060.89
# Chips and Guacamole     512.44
# Steak Bowl              420.05
# Name: revenue, dtype: float64
