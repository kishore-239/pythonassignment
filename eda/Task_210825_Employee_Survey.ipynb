# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# %%
import numpy as np 
import os

import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\kisho\OneDrive\Desktop\All semesters\Innomatics #405\2_EDA\Task_210825_Employee_Survey\employee_survey.csv")
df
# Out:
#       EmpID  Gender  Age MaritalStatus        JobLevel  Experience       Dept  \
# 0         6    Male   32       Married             Mid           7         IT
# 1        11  Female   34       Married             Mid          12    Finance
# 2        33  Female   23        Single  Intern/Fresher           1  Marketing
# 3        20  Female   29       Married          Junior           6         IT
# 4        28   Other   23        Single          Junior           1      Sales
# ...     ...     ...  ...           ...             ...         ...        ...
# 3020   2070    Male   47       Married            Lead          16  Marketing
# 3021   2072  Female   47       Married            Lead           8         IT
# 3022   2145    Male   41       Married            Lead          17         IT
# 3023   2168  Female   54       Married            Lead          16         IT
# 3024   2183  Female   44       Married            Lead          22  Marketing
#
# ...

# %%
df.head()
df.tail()
df.shape
df.columns
df.dtypes
df.info()
# Out:
#    EmpID  Gender  Age MaritalStatus        JobLevel  Experience       Dept  \
# 0      6    Male   32       Married             Mid           7         IT
# 1     11  Female   34       Married             Mid          12    Finance
# 2     33  Female   23        Single  Intern/Fresher           1  Marketing
# 3     20  Female   29       Married          Junior           6         IT
# 4     28   Other   23        Single          Junior           1      Sales
#
#      EmpType  WLB  WorkEnv  ...  SleepHours       CommuteMode  \
# 0  Full-Time    1        1  ...         7.6               Car
# 1  Full-Time    1        1  ...         7.9               Car
# 2  Full-Time    2        4  ...         6.5         Motorbike
# 3   Contract    2        2  ...         7.5  Public Transport
# 4  Part-Time    3        1  ...         4.9               Car
#
#    CommuteDistance  NumCompanies TeamSize  NumReports  EduLevel  haveOT  \
# ...

# %%
df.describe()
df.describe(include='all')
df.isnull().sum()
df.nunique()
df['Dept'].unique()
# Out:
#              EmpID          Age   Experience          WLB      WorkEnv  \
# count  3025.000000  3025.000000  3025.000000  3025.000000  3025.000000
# mean   1513.000000    35.741818     9.082645     3.061157     3.029091
# std     873.386608    10.191833     7.073344     1.447001     1.415317
# min       1.000000    22.000000     0.000000     1.000000     1.000000
# 25%     757.000000    27.000000     3.000000     2.000000     2.000000
# 50%    1513.000000    34.000000     8.000000     3.000000     3.000000
# 75%    2269.000000    43.000000    14.000000     4.000000     4.000000
# max    3025.000000    60.000000    29.000000     5.000000     5.000000
#
#        PhysicalActivityHours     Workload       Stress   SleepHours  \
# count            3025.000000  3025.000000  3025.000000  3025.000000
# mean                2.029620     2.966612     1.736529     7.005983
# std                 0.966014     1.401486     1.064242     1.002652
# ...

# %% [markdown]
# ### 1. How satisfied are employees with their current roles based on survey responses?

# %%
df['JobSatisfaction'].value_counts()
# Out:
# JobSatisfaction
# 4    1249
# 3     566
# 5     516
# 1     417
# 2     277
# Name: count, dtype: int64

# %% [markdown]
# ### 3. What is the average job satisfaction score for each department?

# %%
df.groupby('Dept')['JobSatisfaction'].mean()
# Out:
# Dept
# Customer Service    3.312925
# Finance             3.437991
# HR                  3.398601
# IT                  3.282946
# Legal               3.393382
# Marketing           3.348101
# Operations          3.465934
# Sales               3.498221
# Name: JobSatisfaction, dtype: float64

# %% [markdown]
# ### 4. How many employees are in each age group?

# %%
df['Age'].value_counts().sort_index()
# Out:
# Age
# 22    159
# 23    167
# 24    157
# 25    108
# 26    106
# 27     93
# 28    111
# 29    107
# 30    103
# 31    112
# 32    103
# 33    112
# 34    102
# 35    101
# 36    122
# 37    115
# 38     92
# 39     92
# 40    107
# 41     44
# 42     40
# 43     50
# 44     50
# 45     50
# 46     42
# 47     56
# 48     63
# 49     51
# 50     59
# 51     52
# 52     49
# 53     61
# 54     58
# 55     12
# 56     19
# 57     21
# 58     25
# 59     31
# 60     23
# Name: count, dtype: int64

# %% [markdown]
# ### 5. What is the average years of service for each education level?

# %%
df.groupby('EduLevel')['Experience'].mean()
# Out:
# EduLevel
# Bachelor        9.145652
# High School     1.600000
# Master         11.897368
# PhD            15.270000
# Name: Experience, dtype: float64

# %% [markdown]
# ### 6. Which departments have the highest and lowest employee engagement scores?

# %%
df.groupby('Dept')['WorkEnv'].mean().sort_values(ascending=False)
# Out:
# Dept
# IT                  3.118863
# Operations          3.109890
# Sales               3.049822
# HR                  3.041958
# Legal               3.011029
# Finance             3.009419
# Customer Service    2.938776
# Marketing           2.765823
# Name: WorkEnv, dtype: float64

# %% [markdown]
# ### 7. How many employees in each department have a "Very Satisfied" job satisfaction score?

# %%
df[df['JobSatisfaction'] == 5].groupby('Dept')['EmpID'].count()
# Out:
# Dept
# Customer Service     21
# Finance             124
# HR                   22
# IT                  126
# Legal                36
# Marketing            52
# Operations           84
# Sales                51
# Name: EmpID, dtype: int64

# %% [markdown]
# ### 8. What is the average workload for each job role?

# %%
df.groupby('JobLevel')['Workload'].mean()
# Out:
# JobLevel
# Intern/Fresher    2.965347
# Junior            3.046512
# Lead              3.049223
# Mid               2.889034
# Senior            2.947615
# Name: Workload, dtype: float64

# %% [markdown]
# ### 11. What are the top 5 job roles with the highest average employee engagement scores?

# %%
df.groupby('JobLevel')['WorkEnv'].mean().sort_values(ascending=False).head(5)
# Out:
# JobLevel
# Lead              3.163212
# Intern/Fresher    3.094059
# Senior            3.040225
# Junior            2.990033
# Mid               2.959530
# Name: WorkEnv, dtype: float64

# %% [markdown]
# ### 12. Which employees have the lowest work-life balance scores, sorted by score?

# %%
df[['EmpID', 'Dept', 'JobLevel', 'WLB']].sort_values(by='WLB', ascending=True)
# Out:
#       EmpID              Dept JobLevel  WLB
# 1840     47             Legal   Senior    1
# 2751   1245             Legal   Senior    1
# 2752   1252  Customer Service   Senior    1
# 113    2885        Operations   Senior    1
# 115    2888                IT      Mid    1
# ...     ...               ...      ...  ...
# 11       32             Legal   Senior    5
# 10       18  Customer Service      Mid    5
# 9        15         Marketing      Mid    5
# 36      920           Finance   Junior    5
# 2989   1430           Finance     Lead    5
#
# [3025 rows x 4 columns]

# %% [markdown]
# ### 14. What are the details of employees in the "Sales" department?

# %%
df[df['Dept'] == 'Sales']
# Out:
#       EmpID  Gender  Age MaritalStatus JobLevel  Experience   Dept    EmpType  \
# 4        28   Other   23        Single   Junior           1  Sales  Part-Time
# 6        21  Female   26        Single   Junior           4  Sales  Full-Time
# 15      151    Male   28       Married   Senior           6  Sales  Full-Time
# 16      173  Female   26        Single      Mid           4  Sales  Part-Time
# 45     1200  Female   32       Married   Senior           8  Sales   Contract
# ...     ...     ...  ...           ...      ...         ...    ...        ...
# 2969    991    Male   40       Married     Lead          18  Sales  Full-Time
# 2978   1095  Female   44       Married     Lead           6  Sales   Contract
# 2993    751  Female   50       Married     Lead          21  Sales  Full-Time
# 2995    863    Male   57       Married     Lead          16  Sales  Full-Time
# 2999   1089    Male   56       Married     Lead           4  Sales  Full-Time
#
# ...

# %% [markdown]
# ### 15. How many employees are in the "IT" department and what are their job satisfaction scores?

# %%
df[df['Dept'] == 'IT'][['EmpID', 'JobSatisfaction']]
# Out:
#       EmpID  JobSatisfaction
# 0         6                5
# 3        20                5
# 7        44                5
# 24      406                5
# 33      739                5
# ...     ...              ...
# 3016   1939                1
# 3019   2000                1
# 3021   2072                1
# 3022   2145                1
# 3023   2168                1
#
# [774 rows x 2 columns]

# %% [markdown]
# ### 16. What is the average employee engagement score for the "Marketing" department?

# %%
df[df['Dept'] == 'Marketing']['WorkEnv'].mean()
# Out:
# np.float64(2.7658227848101267)

# %% [markdown]
# ### 17. What is the distribution of employee engagement scores across all employees?

# %%
df['WorkEnv'].value_counts().sort_index()
# Out:
# WorkEnv
# 1    580
# 2    604
# 3    631
# 4    568
# 5    642
# Name: count, dtype: int64

# %% [markdown]
# ### 18. How many employees belong to each job role?

# %%
df['JobLevel'].value_counts()
# Out:
# JobLevel
# Senior            1069
# Mid                766
# Junior             602
# Lead               386
# Intern/Fresher     202
# Name: count, dtype: int64
