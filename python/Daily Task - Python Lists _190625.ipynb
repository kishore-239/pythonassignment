# %% [markdown]
# ## Daily Task

# %% [markdown]
# ### 1. Create a list fruits = ['apple', 'banana', 'cherry', 'date']. What is the output of fruits[2]?

# %%
fruits = ['apple', 'banana', 'cherry', 'date']

# %%
print(fruits[2])
# Out:
# cherry

# %%
fruits[2]
# Out:
# 'cherry'

# %% [markdown]
# ### 2. Given numbers = [10, 20, 30, 40, 50], print the first three elements using slicing.

# %%
numbers = [10, 20, 30, 40, 50]

# %%
numbers[:3]
# Out:
# [10, 20, 30]

# %% [markdown]
# ### 3. What does colors = ['red', 'green', 'blue', 'yellow']; colors[1:3] return?

# %%
colors = ['red', 'green', 'blue', 'yellow']; colors[1:3]
# Out:
# ['green', 'blue']

# %% [markdown]
# ### 4. Create a list with 6 elements and extract the last 2 elements using positive slicing only.

# %%
import random

list_1 = [random.randint(1, 100) for i in range(6)]

# %%
last_two = list_1[4:6]

# %%
print("complete list:", list_1)
print("Last two elements:", last_two)
# Out:
# complete list: [47, 31, 24, 91, 62, 32]
# Last two elements: [62, 32]

# %% [markdown]
# ### 5. Given items = ['pen', 'pencil', 'eraser', 'sharpener', 'scale'], what does items[:4] return?

# %%
items = ['pen', 'pencil', 'eraser', 'sharpener', 'scale']

# %%
items[:4]
# Out:
# ['pen', 'pencil', 'eraser', 'sharpener']

# %% [markdown]
# ### 6. Start with tools = ['hammer', 'wrench'] and append 'screwdriver'. What does tools look like after?

# %%
tools = ['hammer', 'wrench']
tools.append('screwdriver')

# %%
print(tools)
# Out:
# ['hammer', 'wrench', 'screwdriver']

# %% [markdown]
# ### 7. Use append() to add a sublist [1, 2] to the list data = [0]. What is the result?

# %%
data = [0]

# %%
data.append([1, 2])

# %%
data
# Out:
# [0, [1, 2]]

# %% [markdown]
# ### 8. If words = [], how many times must you call words.append('hello') to get ['hello', 'hello', 'hello']?

# %%
words = []

# %%
words.append('hello')

# %%
words
# Out:
# ['hello']

# %%
words.append('hello')

# %%
words.append('hello')

# %%
words
# Out:
# ['hello', 'hello', 'hello']

# %% [markdown]
# ###### you must call 3 times to get ['hello', 'hello', 'hello']

# %% [markdown]
# ### 9. Given nums = [1, 2, 4, 5], use insert() to add 3 at the correct position to make it [1, 2, 3, 4, 5].

# %%
nums = [1, 2, 4, 5]

# %%
nums.insert(2,3)

# %%
print(nums)
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# ### 10. Start with letters = ['a', 'b', 'd']. Insert 'c' at index 2. What does the list become?

# %%
letters = ['a', 'b', 'd']

# %%
letters.insert(2,'c')

# %%
print(letters)
# Out:
# ['a', 'b', 'c', 'd']

# %% [markdown]
# ### 11. If nums = [10, 20, 30], what does nums.insert(1, 15) do?

# %%
nums = [10, 20, 30]

# %%
nums.insert(1, 15)

# %%
print(nums)
# Out:
# [10, 15, 20, 30]

# %% [markdown]
# ### 12. Given a = [1, 2, 2, 3, 2], what is a.count(2)?

# %%
a = [1, 2, 2, 3, 2]

# %%
a.count(2)
# Out:
# 3

# %% [markdown]
# ### 13. If items = ['cat', 'dog', 'cat', 'fish'], how many times does 'cat' appear?

# %%
items = ['cat', 'dog', 'cat', 'fish']

# %%
items.count('cat')
# Out:
# 2

# %% [markdown]
# ### 14. What is the output of ['a', 'b', 'a', 'a'].count('a')?

# %%
['a', 'b', 'a', 'a'].count('a')
# Out:
# 3

# %% [markdown]
# ### 15. Convert the string 'hello' into a list using list(). What’s the result?

# %%
var = 'hello'

# %%
var = list('hello')

# %%
var
# Out:
# [10, 20, 30]

# %%
type(var)
# Out:
# list

# %% [markdown]
# ### 16. What does list((1, 2, 3)) return?

# %%
list((1, 2, 3))
# Out:
# [1, 2, 3]

# %% [markdown]
# ### 17. Use list() to convert a set {10, 20, 30} to a list. What happens?

# %%
var = {10, 20, 30}

# %%
var = list({10, 20, 30})

# %%
var
print(type(var))
# Out:
# <class 'list'>

# %% [markdown]
# ### 18. Create a nested list nested = [[1, 2], [3, 4]]. How do you access the number 3?

# %%
nested = [[1, 2], [3, 4]]

# %%
nested[1][0]
# Out:
# 3

# %% [markdown]
# ### 19.What is the result of matrix = [[10, 20], [30, 40]]; matrix[1][1]?

# %%
 matrix = [[10, 20], [30, 40]]; matrix[1][1]
# Out:
# 40

# %% [markdown]
# ### 20. Given nested = [['a', 'b'], ['c', 'd']], how do you get 'd'?

# %%
nested = [['a', 'b'], ['c', 'd']]

# %%
nested[1][1]
# Out:
# 'd'

# %% [markdown]
# ### 21.Given x = [1, 2, 3], use append() and insert() to make it [0, 1, 2, 3, 4].

# %%
x = [1, 2, 3]

# %%
x.insert(0,0)
x.append(4)

# %%
print(x)
# Out:
# [0, 1, 2, 3, 4]

# %% [markdown]
# ### 22. Start with a = ['x', 'y'], append 'z', then count how many times 'z' appears.

# %%
a = ['x', 'y']

# %%
a.append('z')
a.count('z')
# Out:
# 1

# %% [markdown]
# ### 23. Given data = ['one', 'two', 'three'], slice the list to get only ['two', 'three'].

# %%
data = ['one', 'two', 'three']

# %%
data[1:]
# Out:
# ['two', 'three']

# %% [markdown]
# ### 24. Use insert() on an empty list a = [] to add 'first' at position 0.

# %%
a = []

# %%
a.insert(0,'first')

# %%
print(a)
# Out:
# ['first']

# %% [markdown]
# ### 25. Given nums = [100, 200, 300], append [400, 500]. What is the structure of nums now?

# %%
nums = [100, 200, 300]

# %%
nums.append([400, 500])

# %%
nums
# Out:
# [100, 200, 300, [400, 500]]
