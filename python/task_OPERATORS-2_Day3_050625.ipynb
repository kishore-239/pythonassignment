# %% [markdown]
# ## OPERATORS-2

# %% [markdown]
# ### Q.1.  A baker made 24 cupcakes and packed them into boxes of 6. How many boxes did he fill?

# %%
cupcakes = 24
box = 6

# %%
total_boxes = cupcakes // box

# %%
print(total_boxes)
# Out:
# 4

# %% [markdown]
# ### Q.2.   Lily had 50 coins. After donating 15, how many coins does she have left?

# %%
coins = 50
donated = 15

# %%
left_coins = coins - donated

# %%
print(left_coins)
# Out:
# 35

# %% [markdown]
# ### Q.3.   A magician pulls 3 rabbits from each of his 4 hats. How many rabbits appear in total?

# %%
hats = 4
rabbits = 3 # from each hat

# %%
total_rabbits = hats * rabbits

# %%
print(total_rabbits)
# Out:
# 12

# %% [markdown]
# ### Q.4.   A car travels 180 km in 3 hours. What is its average speed?

# %%
distance = 180
time = 3

# %%
avg_speed = distance // time

# %%
print(avg_speed)
# Out:
# 60

# %% [markdown]
# ### Q.5.   A student scored 78 in English and 91 in History. Did they score higher in History?

# %%
english = 78
history = 91

# %%
if english < history:
    print("Yes, they score higher in History ")
else:
    print("No, they didn't score higher in History ")
# Out:
# Yes, they score higher in History

# %% [markdown]
# ### Q.6.   You earn 15 an hour and worked 8 hours. Did you earn at least 120?

# %%
earn = 15
worked = 8

# %%
total = earn * worked

# %%
if total >= 120:
    print("Yes, he earn atleast 120")
else:
    print("No, he didnt earn")
# Out:
# Yes, he earn atleast 120

# %% [markdown]
# ### Q.7.   A library has 12 fiction and 9 non-fiction books. Is the total book count more than 20?

# %%
fiction = 12
non_fiction = 9

# %%
total = fiction + non_fiction

# %%
if total > 20:
    print("yes, total book count is more than 20")
else:
    print("No, total book count is not more than 20")
# Out:
# yes, total book count is more than 20

# %% [markdown]
# ### Q.8.    A zoo has 7 lions and 7 tigers. Do they have an equal number of both animals?

# %%
lions = 7
tigers = 7

# %%
if lions == tigers:
    print("Yes, they do have an equal number of both animals")
else:
    print("No, they don't have an equal number of both animals")
# Out:
# Yes, they do have an equal number of both animals

# %% [markdown]
# ### Q.9.     Two siblings share 18 candies equally. How many does each get?

# %%
candies = 18
siblings = 2
each_sibling = candies // siblings

# %%
print(f"each sibling gets {each_sibling} candies")
# Out:
# each sibling gets 9 candies

# %% [markdown]
# ### Q.10.   A bottle holds 500ml. You drank 125ml twice. Is more than half still left?

# %%
bottle = 500
drank = 125 * 2

# %%
reamining = bottle - drank

# %%
if reamining > 500/2:
    print("Yes, more than half is still left")
else:
    print("No, more than half isn't still left")
# Out:
# No, more than half isn't still left

# %% [markdown]
# ### Q.11.     The sum of your ages and your dog’s age is 30. If you are 25, how old is your dog?

# %%
your_age = 25
sum = 30

# %%
dog = sum - your_age

# %%
print(f"age of your dog is {dog} years old")
# Out:
# age of your dog is 5 years old

# %% [markdown]
# ### Q.12.    Two friends both have 100 points in a game. Do they have identical scores?

# %%
friend1 = 100
friend2 = 100

# %%
if friend1 == friend2:
    print("Yes, they have identical scores.")
else:
    print("No, they do not have identical scores.")
# Out:
# Yes, they have identical scores.

# %% [markdown]
# ### Q.13.    A farmer harvested 120 apples and stored them in crates of 10. How many crates did he use?

# %%
apples = 120
each_crate = 10

# %%
total_crates = apples // each_crate

# %%
print(f"The farmer used {total_crates} crates.")
# Out:
# The farmer used 12 crates.

# %% [markdown]
# ### Q.14.    Multiply 7 by 3 and compare if the result is greater than 20.

# %%
product = 7 * 3

# %%
if product > 20:
    print("Yes, the result is greater than 20")
else:
    print("No, the result isn't greater than 20")
# Out:
# Yes, the result is greater than 20

# %% [markdown]
# ### Q.15.   If you walk 3 km and run 2 km, is your total distance equal to 5 km?

# %%
walk = 3
run = 2

# %%
total = walk + run

# %%
if total == 5:
    print("Yes, your total distance equal to 5 km")
else:
    print("No, your total distance is not equal to 5 km")
# Out:
# Yes, your total distance equal to 5 km

# %% [markdown]
# ### Q.16.     Is it true that 5 is greater than 2 and also less than 10?

# %%
if 5 > 2 and 5 < 10:
    print("It is true")
else:
    print("It is false")
# Out:
# It is true

# %% [markdown]
# ### Q.17.    Is either 7 less than 4 or 9 equal to 9?

# %%
if 7 < 4 or 9 == 9:
    print("True")
else:
    print("False")
# Out:
# True

# %% [markdown]
# ### Q.18.    Create two strings: x = "hello", y = "hello". Are they the same object in memory?

# %%
x = "hello"
y = "hello"

# %%
if x is y:
    print("yes, they are the same object in memory")
else:
    print("No, they aren't the same object in memory")
# Out:
# yes, they are the same object in memory

# %% [markdown]
# ### Q.19.     You added 20 points to your score of 60. What’s your new score?

# %%
score = 60
points_added = 20

# %%
new_score = score + points_added

# %%
print(f"Your new score is {new_score}")
# Out:
# Your new score is 80

# %% [markdown]
# ### Q.20.    If x = 100 and x -= 40, what is the value of x now?

# %%
x = 100

# %%
x -= 40

# %%
print(f"The value of x is {x}")
# Out:
# The value of x is 60

# %% [markdown]
# ### Q.21.    Start with y = 10, then double it using the assignment operator. What’s y?

# %%
y = 10
y *= 2

# %%
print(f"Now the value of y is {y}")
# Out:
# Now the value of y is 20

# %% [markdown]
# ### Q.22.    Divide 80 by 4 using the /= operator. What's the result?

# %%
x = 80
x /= 4

# %%
print(f"the result is {x}")
# Out:
# the result is 20.0

# %% [markdown]
# ### Q.23.     Check if 9 is not equal to 8 using a comparison operator.

# %%
a = 9 != 8

# %%
print(f"{a}, that 9 is not equal to 8")
# Out:
# True, that 9 is not equal to 8

# %% [markdown]
# ### Q.24.    You have x = None. Is x identical to None?

# %%
x = None

# %%
if x is None:
    print("Yes, x is identical to None")
else:
    print("No, x is not identical to None")
# Out:
# Yes, x is identical to None

# %% [markdown]
# ### Q.25.    Are 3.0 and 3 considered the same object using the identity operator?

# %%
x = 3
y = 3.0

# %%
print(x is y)
# Out:
# False

# %% [markdown]
# ### Q.26.     A puzzle has 9 parts. If 3 are missing, how many remain?

# %%
puzzle = 9
missing = 3

# %%
remaining = puzzle - missing

# %%
print(f"remaining parts are {remaining}")
# Out:
# remaining parts are 6

# %% [markdown]
# ### Q.27.     If x = 10 and y = 5, is x + y equal to x * y?

# %%
x = 10
y = 5

# %%
a = x + y
b = x * y

# %%
if a == b:
    print("Yes, they are equal")
else:
    print("No, they are not equal")
# Out:
# No, they are not equal

# %% [markdown]
# ### Q.28.     If you study 2 hours daily for 7 days, how many total hours is that?

# %%
daily = 2
days = 7

# %%
total = daily * days

# %%
print(f"total hours is {total}")
# Out:
# total hours is 14

# %% [markdown]
# ### Q.29.     You received 100 messages, deleted 25. Are you left with more than 70?

# %%
messages = 100
deleted = 25

# %%
remaining = messages - deleted

# %%
if remaining > 70:
    print("yes, I left with more than 70")
else:
    print("No, I do not left with more than 70")
# Out:
# yes, I left with more than 70

# %% [markdown]
# ### Q.30.     You multiply your savings by 2 every year. If you start with 300, what do you have after doubling once?

# %%
x = 300
x *= 2

# %%
print(f"After doubling once you have {x}")
# Out:
# After doubling once you have 600
