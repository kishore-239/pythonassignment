# %% [markdown]
# ### Q1. Write a program to check whether the last digit of a number (entered by user) is divisible by 3 or not.

# %%
number = int(input("Enter a number: "))

last_digit = abs(number) % 10  # abs() handles negative numbers

if last_digit % 3 == 0:
    print(f"The last digit ({last_digit}) is divisible by 3.")
else:
    print(f"The last digit ({last_digit}) is not divisible by 3.")
# Out:
# Enter a number:  79
# The last digit (9) is divisible by 3.

# %% [markdown]
# ### Q2. A company decided to give a bonus of 5% of their salary to employees if his/her years of service is more than 5 years.
# ### Ask the user for their salary and years of service and print the net amount of that person.

# %%
salary = float(input("Enter your salary: "))
years_of_service = int(input("Enter your years of service: "))

if years_of_service > 5:
    bonus = salary * 0.05
    net_salary = salary + bonus
    print(f"Congratulations! You get a bonus of ₹{bonus:.2f}")
    print(f"Your net salary is ₹{net_salary:.2f}")
else:
    print(f"No bonus applicable. Your salary remains ₹{salary:.2f}")
# Out:
# Enter your salary:  78000.99
# Enter your years of service:  7
# Congratulations! You get a bonus of ₹3900.05
# Your net salary is ₹81901.04

# %% [markdown]
# ### Q3. A school has following rules for grading system:
# ##### a. Below 25 - F grade
# ##### b. 25 to 45 - E
# ##### c. 45 to 50 - D
# ##### d. 50 to 60 - C
# ##### e. 60 to 80 - B
# ##### f. Above 80 - A
# ##### Ask the user to enter marks and print the corresponding grade.

# %%
marks = float(input("Enter your marks: "))

if marks < 25:
    grade = 'F'
elif 25 <= marks < 45:
    grade = 'E'
elif 45 <= marks < 50:
    grade = 'D'
elif 50 <= marks < 60:
    grade = 'C'
elif 60 <= marks < 80:
    grade = 'B'
else:
    grade = 'A'  # For marks 80 and above

print(f"Your grade is: {grade}")
# Out:
# Enter your marks:  97
# Your grade is: A

# %% [markdown]
# ### Q4. Write a python program that can tell you if your sugar is normal or not. Normal fasting level sugar range is 80 to 100.
# #### Ask the user to enter his fasting sugar level.
# #### If it is below 80, then print that sugar is low.
# #### If it is above 100, then print that it is high
# #### Otherwise print that it is normal.

# %%
sugar_level = float(input("Enter your fasting sugar level (mg/dL): "))

if sugar_level < 80:
    print("Your sugar level is low.")
elif sugar_level > 100:
    print("Your sugar level is high.")
else:
    print("Your sugar level is normal.")
# Out:
# Enter your fasting sugar level (mg/dL):  97
# Your sugar level is normal.

# %% [markdown]
# ### Q5. Write a program which will accept a word and a number from the user. Check if the word starts with a vowel and the number is even and write appropriate conditions accordingly (Case sensitivity should not matter).
#
# ##### Example :
# ##### Innoamtics, 6 --- both the conditions are satisfied
# ##### innomatics, 5--- at least one condition is satisfied
# ##### Ramya, 6--- at least one condition is satisfied
# ##### ramya , 5 --- none of the conditions are satisfied

# %%
word = input("Enter a word: ")
number = int(input("Enter a number: "))

lower_word = word.lower()

# Check conditions
starts_with_vowel = lower_word[0] in ['a', 'e', 'i', 'o', 'u']
is_even = number % 2 == 0

if starts_with_vowel and is_even:
    print(f"{word}, {number} --- both the conditions are satisfied")
elif starts_with_vowel or is_even:
    print(f"{word}, {number} --- at least one condition is satisfied")
else:
    print(f"{word}, {number} --- none of the conditions are satisfied")
# Out:
# Enter a word:  eroshik
# Enter a number:  18
# eroshik, 18 --- both the conditions are satisfied

# %% [markdown]
# ### Q6. Take input from the user. Check if a given year is a leap year.
#     ##### Example:
#     ##### Enter a year: 2022
#     ##### 2022 is not a leap year

# %%
year = int(input("Enter a year: "))

if (year % 400 == 0) or (year % 100 != 0 and year % 4 == 0):
    print(f"{year} is a leap year")
else:
    print(f"{year} is not a leap year")
# Out:
# Enter a year:  2028
# 2028 is a leap year

# %% [markdown]
# ### b. Given a sentence, determine if it is a statement, question, or exclamation.
# ##### Example:
# ##### Enter a sentence: What a beautiful day!
# ##### Output: Exclamation
# #####
# ##### Enter a sentence: No class today?
# ##### Output: Question
# #####
# ##### Enter a sentence: Elizabeth has eleven elves in her elm tree.
# ##### Output: Statement
# #####
# ##### Enter a sentence: Yes
# ##### Output: Unknown type

# %%
sentence = input("Enter a sentence: ").strip()

if len(sentence) == 0:
    print("Unknown type")
elif sentence.endswith('?'):
    print("Question")
elif sentence.endswith('!'):
    print("Exclamation")
elif sentence.endswith('.'):
    print("Statement")
else:
    print("Unknown type")
# Out:
# Enter a sentence:  kishore!?.
# Statement
